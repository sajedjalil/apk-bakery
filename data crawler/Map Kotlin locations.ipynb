# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-py39_4.11.0-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX

# %%
import sys
sys.path.append('/usr/local/lib/python3.10/site-packages/')

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !conda create -n mlfeed python=3.10

# %%
# %%bash
# conda init bash

# %%
# %%bash
# exec bash

# %%
# %%bash
# conda activate mlfeed

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                  *  /usr/local

# %%
# !source activate mlfeed

# %%
# !python3 --version
# !which python
# Out:
# Python 3.9.7
# /usr/local/bin/python

# %%
from openpyxl import load_workbook
import pandas as pd
from kopyt import Parser, node
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-c76035d0e05f> in <module>()
#       1 from openpyxl import load_workbook
#       2 import pandas as pd
# ----> 3 from kopyt import Parser, node
#
# ModuleNotFoundError: No module named 'kopyt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
